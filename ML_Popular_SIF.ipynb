# %%
import pandas as pd
songs_df = pd.read_csv("spotify_songs.csv")
songs_df.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               2019-06-14
# 1                    Memories (Dillon Francis Remix)               2019-12-13
# 2                    All the Time (Don Diablo Remix)               2019-07-05
# 3                        Call You Mine - The Remixes               2019-07-19
# 4            Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %%
songs_df_pp = songs_df.drop(["track_id","track_name",'track_artist',"track_album_id",'track_album_name','playlist_name','playlist_id'],axis=1)
songs_df_pp.head()
# Out:
#    track_popularity track_album_release_date playlist_genre playlist_subgenre  \
# 0                66               2019-06-14            pop         dance pop
# 1                67               2019-12-13            pop         dance pop
# 2                70               2019-07-05            pop         dance pop
# 3                60               2019-07-19            pop         dance pop
# 4                69               2019-03-05            pop         dance pop
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916    6    -2.634     1       0.0583        0.1020
# 1         0.726   0.815   11    -4.969     1       0.0373        0.0724
# 2         0.675   0.931    1    -3.432     0       0.0742        0.0794
# 3         0.718   0.930    7    -3.778     1       0.1020        0.0287
# 4         0.650   0.833    1    -4.672     1       0.0359        0.0803
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000000    0.0653    0.518  122.036       194754
# 1          0.004210    0.3570    0.693   99.972       162600
# 2          0.000023    0.1100    0.613  124.008       176616
# 3          0.000009    0.2040    0.277  121.956       169093
# 4          0.000000    0.0833    0.725  123.976       189052

# %%
from datetime import datetime

songs_df_pp['track_album_release_date'] = pd.to_datetime(songs_df_pp['track_album_release_date'], format = "mixed")
songs_df_pp['release_month'] = songs_df_pp['track_album_release_date'].dt.month
songs_df_pp.head()
# Out:
#    track_popularity track_album_release_date playlist_genre playlist_subgenre  \
# 0                66               2019-06-14            pop         dance pop
# 1                67               2019-12-13            pop         dance pop
# 2                70               2019-07-05            pop         dance pop
# 3                60               2019-07-19            pop         dance pop
# 4                69               2019-03-05            pop         dance pop
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916    6    -2.634     1       0.0583        0.1020
# 1         0.726   0.815   11    -4.969     1       0.0373        0.0724
# 2         0.675   0.931    1    -3.432     0       0.0742        0.0794
# 3         0.718   0.930    7    -3.778     1       0.1020        0.0287
# 4         0.650   0.833    1    -4.672     1       0.0359        0.0803
#
#    instrumentalness  liveness  valence    tempo  duration_ms  release_month
# 0          0.000000    0.0653    0.518  122.036       194754              6
# 1          0.004210    0.3570    0.693   99.972       162600             12
# 2          0.000023    0.1100    0.613  124.008       176616              7
# 3          0.000009    0.2040    0.277  121.956       169093              7
# 4          0.000000    0.0833    0.725  123.976       189052              3

# %%
songs_df_pp_encoded = pd.get_dummies(songs_df_pp)
songs_df_pp_encoded.head()
# Out:
#    track_popularity track_album_release_date  danceability  energy  key  \
# 0                66               2019-06-14         0.748   0.916    6
# 1                67               2019-12-13         0.726   0.815   11
# 2                70               2019-07-05         0.675   0.931    1
# 3                60               2019-07-19         0.718   0.930    7
# 4                69               2019-03-05         0.650   0.833    1
#
#    loudness  mode  speechiness  acousticness  instrumentalness  ...  \
# 0    -2.634     1       0.0583        0.1020          0.000000  ...
# 1    -4.969     1       0.0373        0.0724          0.004210  ...
# 2    -3.432     0       0.0742        0.0794          0.000023  ...
# 3    -3.778     1       0.1020        0.0287          0.000009  ...
# 4    -4.672     1       0.0359        0.0803          0.000000  ...
#
#    playlist_subgenre_new jack swing  playlist_subgenre_permanent wave  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    playlist_subgenre_pop edm  playlist_subgenre_post-teen pop  \
# 0                      False                            False
# 1                      False                            False
# 2                      False                            False
# 3                      False                            False
# 4                      False                            False
#
#    playlist_subgenre_progressive electro house  playlist_subgenre_reggaeton  \
# 0                                        False                        False
# 1                                        False                        False
# 2                                        False                        False
# 3                                        False                        False
# 4                                        False                        False
#
#    playlist_subgenre_southern hip hop  playlist_subgenre_trap  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
#
#    playlist_subgenre_tropical  playlist_subgenre_urban contemporary
# 0                       False                                 False
# 1                       False                                 False
# 2                       False                                 False
# 3                       False                                 False
# 4                       False                                 False
#
# [5 rows x 45 columns]

# %%
songs_df_pp_encoded['track_popularity'].value_counts()
# Out:
# track_popularity
# 0      2703
# 1       575
# 57      541
# 60      514
# 51      514
#        ...
# 97       22
# 95       15
# 96        7
# 99        4
# 100       2
# Name: count, Length: 101, dtype: int64

# %%
null_values = songs_df_pp_encoded.isnull().sum()
print(null_values)
# Out:
# track_popularity                               0
# track_album_release_date                       0
# danceability                                   0
# energy                                         0
# key                                            0
# loudness                                       0
# mode                                           0
# speechiness                                    0
# acousticness                                   0
# instrumentalness                               0
# liveness                                       0
# valence                                        0
# tempo                                          0
# duration_ms                                    0
# release_month                                  0
# playlist_genre_edm                             0
# playlist_genre_latin                           0
# playlist_genre_pop                             0
# playlist_genre_r&b                             0
# playlist_genre_rap                             0
# playlist_genre_rock                            0
# playlist_subgenre_album rock                   0
# playlist_subgenre_big room                     0
# playlist_subgenre_classic rock                 0
# playlist_subgenre_dance pop                    0
# playlist_subgenre_electro house                0
# playlist_subgenre_electropop                   0
# playlist_subgenre_gangster rap                 0
# playlist_subgenre_hard rock                    0
# playlist_subgenre_hip hop                      0
# playlist_subgenre_hip pop                      0
# playlist_subgenre_indie poptimism              0
# playlist_subgenre_latin hip hop                0
# playlist_subgenre_latin pop                    0
# playlist_subgenre_neo soul                     0
# playlist_subgenre_new jack swing               0
# playlist_subgenre_permanent wave               0
# playlist_subgenre_pop edm                      0
# playlist_subgenre_post-teen pop                0
# playlist_subgenre_progressive electro house    0
# playlist_subgenre_reggaeton                    0
# playlist_subgenre_southern hip hop             0
# playlist_subgenre_trap                         0
# playlist_subgenre_tropical                     0
# playlist_subgenre_urban contemporary           0
# dtype: int64

# %%
def classify_hit(score):
    if score >= 90:
        return 1
    else:
        return 0

# %%
songs_df_pp_encoded['hit'] = songs_df_pp_encoded['track_popularity'].apply(classify_hit)
songs_df_pp_encoded.head()
# Out:
#    track_popularity track_album_release_date  danceability  energy  key  \
# 0                66               2019-06-14         0.748   0.916    6
# 1                67               2019-12-13         0.726   0.815   11
# 2                70               2019-07-05         0.675   0.931    1
# 3                60               2019-07-19         0.718   0.930    7
# 4                69               2019-03-05         0.650   0.833    1
#
#    loudness  mode  speechiness  acousticness  instrumentalness  ...  \
# 0    -2.634     1       0.0583        0.1020          0.000000  ...
# 1    -4.969     1       0.0373        0.0724          0.004210  ...
# 2    -3.432     0       0.0742        0.0794          0.000023  ...
# 3    -3.778     1       0.1020        0.0287          0.000009  ...
# 4    -4.672     1       0.0359        0.0803          0.000000  ...
#
#    playlist_subgenre_permanent wave  playlist_subgenre_pop edm  \
# 0                             False                      False
# 1                             False                      False
# 2                             False                      False
# 3                             False                      False
# 4                             False                      False
#
#    playlist_subgenre_post-teen pop  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    playlist_subgenre_progressive electro house  playlist_subgenre_reggaeton  \
# 0                                        False                        False
# 1                                        False                        False
# 2                                        False                        False
# 3                                        False                        False
# 4                                        False                        False
#
#    playlist_subgenre_southern hip hop  playlist_subgenre_trap  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
#
#    playlist_subgenre_tropical  playlist_subgenre_urban contemporary  hit
# 0                       False                                 False    0
# 1                       False                                 False    0
# 2                       False                                 False    0
# 3                       False                                 False    0
# 4                       False                                 False    0
#
# [5 rows x 46 columns]

# %%
songs_df_pp_encoded['release_day'] = songs_df_pp_encoded['track_album_release_date'].dt.day
songs_df_pp_encoded.head()
# Out:
#    track_popularity track_album_release_date  danceability  energy  key  \
# 0                66               2019-06-14         0.748   0.916    6
# 1                67               2019-12-13         0.726   0.815   11
# 2                70               2019-07-05         0.675   0.931    1
# 3                60               2019-07-19         0.718   0.930    7
# 4                69               2019-03-05         0.650   0.833    1
#
#    loudness  mode  speechiness  acousticness  instrumentalness  ...  \
# 0    -2.634     1       0.0583        0.1020          0.000000  ...
# 1    -4.969     1       0.0373        0.0724          0.004210  ...
# 2    -3.432     0       0.0742        0.0794          0.000023  ...
# 3    -3.778     1       0.1020        0.0287          0.000009  ...
# 4    -4.672     1       0.0359        0.0803          0.000000  ...
#
#    playlist_subgenre_pop edm  playlist_subgenre_post-teen pop  \
# 0                      False                            False
# 1                      False                            False
# 2                      False                            False
# 3                      False                            False
# 4                      False                            False
#
#    playlist_subgenre_progressive electro house  playlist_subgenre_reggaeton  \
# 0                                        False                        False
# 1                                        False                        False
# 2                                        False                        False
# 3                                        False                        False
# 4                                        False                        False
#
#    playlist_subgenre_southern hip hop  playlist_subgenre_trap  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
#
#    playlist_subgenre_tropical  playlist_subgenre_urban contemporary  hit  \
# 0                       False                                 False    0
# 1                       False                                 False    0
# 2                       False                                 False    0
# 3                       False                                 False    0
# 4                       False                                 False    0
#
#    release_day
# 0           14
# 1           13
# 2            5
# 3           19
# 4            5
#
# [5 rows x 47 columns]

# %%
songs_df_pp_encoded = songs_df_pp_encoded.drop(['track_popularity'], axis=1)
songs_df_pp_encoded.head()
# Out:
#   track_album_release_date  danceability  energy  key  loudness  mode  \
# 0               2019-06-14         0.748   0.916    6    -2.634     1
# 1               2019-12-13         0.726   0.815   11    -4.969     1
# 2               2019-07-05         0.675   0.931    1    -3.432     0
# 3               2019-07-19         0.718   0.930    7    -3.778     1
# 4               2019-03-05         0.650   0.833    1    -4.672     1
#
#    speechiness  acousticness  instrumentalness  liveness  ...  \
# 0       0.0583        0.1020          0.000000    0.0653  ...
# 1       0.0373        0.0724          0.004210    0.3570  ...
# 2       0.0742        0.0794          0.000023    0.1100  ...
# 3       0.1020        0.0287          0.000009    0.2040  ...
# 4       0.0359        0.0803          0.000000    0.0833  ...
#
#    playlist_subgenre_pop edm  playlist_subgenre_post-teen pop  \
# 0                      False                            False
# 1                      False                            False
# 2                      False                            False
# 3                      False                            False
# 4                      False                            False
#
#    playlist_subgenre_progressive electro house  playlist_subgenre_reggaeton  \
# 0                                        False                        False
# 1                                        False                        False
# 2                                        False                        False
# 3                                        False                        False
# 4                                        False                        False
#
#    playlist_subgenre_southern hip hop  playlist_subgenre_trap  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
#
#    playlist_subgenre_tropical  playlist_subgenre_urban contemporary  hit  \
# 0                       False                                 False    0
# 1                       False                                 False    0
# 2                       False                                 False    0
# 3                       False                                 False    0
# 4                       False                                 False    0
#
#    release_day
# 0           14
# 1           13
# 2            5
# 3           19
# 4            5
#
# [5 rows x 46 columns]

# %%
songs_df_pp_encoded = songs_df_pp_encoded.drop(['track_album_release_date'], axis=1)
songs_df_pp_encoded.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.748   0.916    6    -2.634     1       0.0583        0.1020
# 1         0.726   0.815   11    -4.969     1       0.0373        0.0724
# 2         0.675   0.931    1    -3.432     0       0.0742        0.0794
# 3         0.718   0.930    7    -3.778     1       0.1020        0.0287
# 4         0.650   0.833    1    -4.672     1       0.0359        0.0803
#
#    instrumentalness  liveness  valence  ...  playlist_subgenre_pop edm  \
# 0          0.000000    0.0653    0.518  ...                      False
# 1          0.004210    0.3570    0.693  ...                      False
# 2          0.000023    0.1100    0.613  ...                      False
# 3          0.000009    0.2040    0.277  ...                      False
# 4          0.000000    0.0833    0.725  ...                      False
#
#    playlist_subgenre_post-teen pop  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
#    playlist_subgenre_progressive electro house  playlist_subgenre_reggaeton  \
# 0                                        False                        False
# 1                                        False                        False
# 2                                        False                        False
# 3                                        False                        False
# 4                                        False                        False
#
#    playlist_subgenre_southern hip hop  playlist_subgenre_trap  \
# 0                               False                   False
# 1                               False                   False
# 2                               False                   False
# 3                               False                   False
# 4                               False                   False
#
#    playlist_subgenre_tropical  playlist_subgenre_urban contemporary  hit  \
# 0                       False                                 False    0
# 1                       False                                 False    0
# 2                       False                                 False    0
# 3                       False                                 False    0
# 4                       False                                 False    0
#
#    release_day
# 0           14
# 1           13
# 2            5
# 3           19
# 4            5
#
# [5 rows x 45 columns]

# %%
songs_df_pp_encoded['release_month'] = songs_df_pp_encoded['release_month'].astype(int)
songs_df_pp_encoded['release_day'] = songs_df_pp_encoded['release_day'].astype(int)

# %%
songs_df_pp_encoded.dtypes
# Out:
# danceability                            float64
# energy                                  float64
# key                                       int64
# loudness                                float64
# mode                                      int64
#                                          ...
# playlist_subgenre_southern hip hop         bool
# playlist_subgenre_trap                     bool
# playlist_subgenre_tropical                 bool
# playlist_subgenre_urban contemporary       bool
# hit                                       int64
# Length: 4573, dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

y = songs_df_pp_encoded['hit'].values
X = songs_df_pp_encoded.drop(columns="hit").values

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Quick Exploratory Data Analysis beforre building the model
# Check for Missing Values
print(songs_df_pp_encoded.isnull().sum())

# Check for Missing Values:
print(songs_df_pp_encoded.describe())
# Out:
# danceability                                   0
# energy                                         0
# key                                            0
# loudness                                       0
# mode                                           0
# speechiness                                    0
# acousticness                                   0
# instrumentalness                               0
# liveness                                       0
# valence                                        0
# tempo                                          0
# duration_ms                                    0
# release_month                                  0
# playlist_genre_edm                             0
# playlist_genre_latin                           0
# playlist_genre_pop                             0
# playlist_genre_r&b                             0
# playlist_genre_rap                             0
# playlist_genre_rock                            0
# playlist_subgenre_album rock                   0
# playlist_subgenre_big room                     0
# playlist_subgenre_classic rock                 0
# playlist_subgenre_dance pop                    0
# playlist_subgenre_electro house                0
# playlist_subgenre_electropop                   0
# playlist_subgenre_gangster rap                 0
# playlist_subgenre_hard rock                    0
# playlist_subgenre_hip hop                      0
# playlist_subgenre_hip pop                      0
# playlist_subgenre_indie poptimism              0
# playlist_subgenre_latin hip hop                0
# playlist_subgenre_latin pop                    0
# playlist_subgenre_neo soul                     0
# playlist_subgenre_new jack swing               0
# playlist_subgenre_permanent wave               0
# playlist_subgenre_pop edm                      0
# playlist_subgenre_post-teen pop                0
# playlist_subgenre_progressive electro house    0
# playlist_subgenre_reggaeton                    0
# playlist_subgenre_southern hip hop             0
# playlist_subgenre_trap                         0
# playlist_subgenre_tropical                     0
# playlist_subgenre_urban contemporary           0
# hit                                            0
# release_day                                    0
# dtype: int64
#        danceability        energy           key      loudness          mode  \
# count  32833.000000  32833.000000  32833.000000  32833.000000  32833.000000
# mean       0.654850      0.698619      5.374471     -6.719499      0.565711
# std        0.145085      0.180910      3.611657      2.988436      0.495671
# min        0.000000      0.000175      0.000000    -46.448000      0.000000
# 25%        0.563000      0.581000      2.000000     -8.171000      0.000000
# 50%        0.672000      0.721000      6.000000     -6.166000      1.000000
# 75%        0.761000      0.840000      9.000000     -4.645000      1.000000
# max        0.983000      1.000000     11.000000      1.275000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  32833.000000  32833.000000      32833.000000  32833.000000
# mean       0.107068      0.175334          0.084747      0.190176
# std        0.101314      0.219633          0.224230      0.154317
# min        0.000000      0.000000          0.000000      0.000000
# 25%        0.041000      0.015100          0.000000      0.092700
# 50%        0.062500      0.080400          0.000016      0.127000
# 75%        0.132000      0.255000          0.004830      0.248000
# max        0.918000      0.994000          0.994000      0.996000
#
#             valence         tempo    duration_ms  release_month           hit  \
# count  32833.000000  32833.000000   32833.000000   32833.000000  32833.000000
# mean       0.510561    120.881132  225799.811622       6.145829      0.009472
# std        0.233146     26.903624   59834.006182       3.833213      0.096865
# min        0.000000      0.000000    4000.000000       1.000000      0.000000
# 25%        0.331000     99.960000  187819.000000       2.000000      0.000000
# 50%        0.512000    121.984000  216000.000000       6.000000      0.000000
# 75%        0.693000    133.918000  253585.000000      10.000000      0.000000
# max        0.991000    239.440000  517810.000000      12.000000      1.000000
#
#         release_day
# count  32833.000000
# mean      13.527305
# std        9.645188
# min        1.000000
# 25%        4.000000
# 50%       13.000000
# 75%       22.000000
# max       31.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograms for numerical features
numerical_features = ['energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness']
songs_df_pp_encoded[numerical_features].hist(bins=30, figsize=(15, 10))
plt.suptitle('Histograms of Numerical Features')
plt.show()

# %%
# Correlation heatmap
correlation_matrix = songs_df_pp_encoded.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Define the model
model = RandomForestClassifier()

# Train the model
model.fit(X_train_scaled, y_train)

# Make predictions
y_pred = model.predict(X_test_scaled)

# Evaluate the model
print(classification_report(y_test, y_pred))

# Feature importance
importances = model.feature_importances_
feature_names = numerical_features + list(songs_df_pp_encoded.drop(columns="hit").columns[len(numerical_features):])

# Create a DataFrame for visualization
feature_importances = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_importances = feature_importances.sort_values(by='Importance', ascending=False)

# Plot feature importances
plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importances)
plt.title('Feature Importances from Random Forest')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8131
#            1       0.95      0.68      0.79        78
#
#     accuracy                           1.00      8209
#    macro avg       0.97      0.84      0.89      8209
# weighted avg       1.00      1.00      1.00      8209

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# %%
input_features = len(X_train_scaled[0])
hidden_layer_1 = 80
hidden_layer_2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_layer_1, activation="relu", input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_layer_2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3600
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 6061 (23.68 KB)
# Trainable params: 6061 (23.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

fit_model = nn.fit(X_train_scaled, y_train, epochs=100)

model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 770/770 [==============================] - 5s 4ms/step - loss: 0.0516 - accuracy: 0.9903
# Epoch 2/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0410 - accuracy: 0.9905
# Epoch 3/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0386 - accuracy: 0.9905
# Epoch 4/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0365 - accuracy: 0.9905
# Epoch 5/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0342 - accuracy: 0.9905
# Epoch 6/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0313 - accuracy: 0.9907
# Epoch 7/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0300 - accuracy: 0.9907
# Epoch 8/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0273 - accuracy: 0.9912
# Epoch 9/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0252 - accuracy: 0.9914
# Epoch 10/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0239 - accuracy: 0.9917
# Epoch 11/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0217 - accuracy: 0.9920
# Epoch 12/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0195 - accuracy: 0.9923
# Epoch 13/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0178 - accuracy: 0.9932
# Epoch 14/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0169 - accuracy: 0.9935
# Epoch 15/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0145 - accuracy: 0.9944
# Epoch 16/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0134 - accuracy: 0.9946
# Epoch 17/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0118 - accuracy: 0.9952
# Epoch 18/100
# 770/770 [==============================] - 3s 3ms/step - loss: 0.0112 - accuracy: 0.9956
# Epoch 19/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0101 - accuracy: 0.9961
# Epoch 20/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0092 - accuracy: 0.9965
# Epoch 21/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0080 - accuracy: 0.9967
# Epoch 22/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0079 - accuracy: 0.9970
# Epoch 23/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0070 - accuracy: 0.9974
# Epoch 24/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0056 - accuracy: 0.9978
# Epoch 25/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0062 - accuracy: 0.9974
# Epoch 26/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0054 - accuracy: 0.9979
# Epoch 27/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 28/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 29/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0043 - accuracy: 0.9984
# Epoch 30/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0038 - accuracy: 0.9986
# Epoch 31/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 32/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0032 - accuracy: 0.9988
# Epoch 33/100
# 770/770 [==============================] - 3s 3ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 34/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 35/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 36/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 37/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0033 - accuracy: 0.9991
# Epoch 38/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 39/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0026 - accuracy: 0.9989
# Epoch 40/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0020 - accuracy: 0.9992
# Epoch 41/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 42/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 43/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0034 - accuracy: 0.9987
# Epoch 44/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0024 - accuracy: 0.9989
# Epoch 45/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 46/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 47/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 48/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 49/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 50/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0016 - accuracy: 0.9993
# Epoch 51/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 52/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 53/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 54/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 55/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 56/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 57/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 58/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 59/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 60/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 61/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 0.9991
# Epoch 62/100
# 770/770 [==============================] - 3s 3ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 63/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 64/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 65/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0010 - accuracy: 0.9996
# Epoch 66/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 67/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 68/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 69/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0011 - accuracy: 0.9997
# Epoch 70/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 71/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 72/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 73/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 74/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 75/100
# 770/770 [==============================] - 3s 4ms/step - loss: 6.7859e-04 - accuracy: 0.9997
# Epoch 76/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 77/100
# 770/770 [==============================] - 2s 3ms/step - loss: 8.4419e-04 - accuracy: 0.9997
# Epoch 78/100
# 770/770 [==============================] - 2s 2ms/step - loss: 8.1949e-04 - accuracy: 0.9996
# Epoch 79/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0028 - accuracy: 0.9989
# Epoch 80/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 81/100
# 770/770 [==============================] - 3s 4ms/step - loss: 6.5346e-04 - accuracy: 0.9998
# Epoch 82/100
# 770/770 [==============================] - 2s 2ms/step - loss: 5.1739e-04 - accuracy: 0.9998
# Epoch 83/100
# 770/770 [==============================] - 2s 2ms/step - loss: 6.4865e-04 - accuracy: 0.9997
# Epoch 84/100
# 770/770 [==============================] - 2s 2ms/step - loss: 8.2653e-04 - accuracy: 0.9997
# Epoch 85/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 86/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 87/100
# 770/770 [==============================] - 2s 3ms/step - loss: 5.1382e-04 - accuracy: 0.9998
# Epoch 88/100
# 770/770 [==============================] - 3s 3ms/step - loss: 6.3090e-04 - accuracy: 0.9997
# Epoch 89/100
# 770/770 [==============================] - 2s 3ms/step - loss: 6.1017e-04 - accuracy: 0.9997
# Epoch 90/100
# 770/770 [==============================] - 2s 2ms/step - loss: 7.9047e-04 - accuracy: 0.9996
# Epoch 91/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0034 - accuracy: 0.9991
# Epoch 92/100
# 770/770 [==============================] - 2s 3ms/step - loss: 7.9068e-04 - accuracy: 0.9996
# Epoch 93/100
# 770/770 [==============================] - 2s 3ms/step - loss: 6.0852e-04 - accuracy: 0.9997
# Epoch 94/100
# 770/770 [==============================] - 2s 3ms/step - loss: 5.5678e-04 - accuracy: 0.9997
# Epoch 95/100
# 770/770 [==============================] - 3s 4ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 96/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 97/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 98/100
# 770/770 [==============================] - 2s 2ms/step - loss: 5.6109e-04 - accuracy: 0.9997
# Epoch 99/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 100/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0016 - accuracy: 0.9994
# 257/257 - 1s - loss: 0.0672 - accuracy: 0.9904 - 621ms/epoch - 2ms/step
# Loss: 0.06723185628652573, Accuracy: 0.9903764128684998

# %%
nn.add(tf.keras.layers.Dense(units=1, activation="linear"))
nn.compile(loss="mse", optimizer="adam")
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
model_loss, model_mse = nn.evaluate(X_test_scaled,y_test,verbose=2)


print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0139
# Epoch 2/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0093
# Epoch 3/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0092
# Epoch 4/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0092
# Epoch 5/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0091
# Epoch 6/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0091
# Epoch 7/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0091
# Epoch 8/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0091
# Epoch 9/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0090
# Epoch 10/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0090
# Epoch 11/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0089
# Epoch 12/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0089
# Epoch 13/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0088
# Epoch 14/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0087
# Epoch 15/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0085
# Epoch 16/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0083
# Epoch 17/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0081
# Epoch 18/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0078
# Epoch 19/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0076
# Epoch 20/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0073
# Epoch 21/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0071
# Epoch 22/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0069
# Epoch 23/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0065
# Epoch 24/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0063
# Epoch 25/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0060
# Epoch 26/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0057
# Epoch 27/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0053
# Epoch 28/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0052
# Epoch 29/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0049
# Epoch 30/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0046
# Epoch 31/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0043
# Epoch 32/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0040
# Epoch 33/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0039
# Epoch 34/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0036
# Epoch 35/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0034
# Epoch 36/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0032
# Epoch 37/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0029
# Epoch 38/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0027
# Epoch 39/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0026
# Epoch 40/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0025
# Epoch 41/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0024
# Epoch 42/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0021
# Epoch 43/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0021
# Epoch 44/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0019
# Epoch 45/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0017
# Epoch 46/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0018
# Epoch 47/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0015
# Epoch 48/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0015
# Epoch 49/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0015
# Epoch 50/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0014
# Epoch 51/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0013
# Epoch 52/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0016
# Epoch 53/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0013
# Epoch 54/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0013
# Epoch 55/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 56/100
# 770/770 [==============================] - 2s 2ms/step - loss: 9.4190e-04
# Epoch 57/100
# 770/770 [==============================] - 2s 3ms/step - loss: 0.0013
# Epoch 58/100
# 770/770 [==============================] - 2s 2ms/step - loss: 0.0013
# Epoch 59/100
# 770/770 [==============================] - 1s 2ms/step - loss: 8.7282e-04
# Epoch 60/100
# 770/770 [==============================] - 1s 2ms/step - loss: 8.8301e-04
# Epoch 61/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0010
# Epoch 62/100
# 770/770 [==============================] - 1s 2ms/step - loss: 0.0012
# Epoch 63/100
# 770/770 [==============================] - 1s 2ms/step - loss: 9.1242e-04
# Epoch 64/100
# 770/770 [==============================] - 1s 2ms/step - loss: 8.1055e-04
# Epoch 65/100
# 770/770 [==============================] - 1s 2ms/step - loss: 7.8072e-04
# Epoch 66/100
# 770/770 [==============================] - 3s 3ms/step - loss: 6.9626e-04
# Epoch 67/100
# 770/770 [==============================] - 3s 4ms/step - loss: 7.0129e-04
# Epoch 68/100
# 770/770 [==============================] - 2s 2ms/step - loss: 8.9821e-04
# Epoch 69/100
# 770/770 [==============================] - 1s 2ms/step - loss: 8.1192e-04
# Epoch 70/100
# 770/770 [==============================] - 1s 2ms/step - loss: 8.5356e-04
# Epoch 71/100
# 770/770 [==============================] - 1s 2ms/step - loss: 6.1298e-04
# Epoch 72/100
# 770/770 [==============================] - 1s 2ms/step - loss: 6.4556e-04
# Epoch 73/100
# 770/770 [==============================] - 1s 2ms/step - loss: 7.5910e-04
# Epoch 74/100
# 770/770 [==============================] - 1s 2ms/step - loss: 6.5234e-04
# Epoch 75/100
# 770/770 [==============================] - 2s 2ms/step - loss: 4.6320e-04
# Epoch 76/100
# 770/770 [==============================] - 2s 3ms/step - loss: 6.9330e-04
# Epoch 77/100
# 770/770 [==============================] - 1s 2ms/step - loss: 5.5577e-04
# Epoch 78/100
# 770/770 [==============================] - 1s 2ms/step - loss: 8.5324e-04
# Epoch 79/100
# 770/770 [==============================] - 1s 2ms/step - loss: 5.4641e-04
# Epoch 80/100
# 770/770 [==============================] - 1s 2ms/step - loss: 4.8543e-04
# Epoch 81/100
# 770/770 [==============================] - 1s 2ms/step - loss: 5.5904e-04
# Epoch 82/100
# 770/770 [==============================] - 1s 2ms/step - loss: 7.8484e-04
# Epoch 83/100
# 770/770 [==============================] - 1s 2ms/step - loss: 6.0246e-04
# Epoch 84/100
# 770/770 [==============================] - 2s 2ms/step - loss: 6.5729e-04
# Epoch 85/100
# 770/770 [==============================] - 3s 4ms/step - loss: 3.8026e-04
# Epoch 86/100
# 770/770 [==============================] - 1s 2ms/step - loss: 3.8738e-04
# Epoch 87/100
# 770/770 [==============================] - 1s 2ms/step - loss: 5.0224e-04
# Epoch 88/100
# 770/770 [==============================] - 1s 2ms/step - loss: 6.4528e-04
# Epoch 89/100
# 770/770 [==============================] - 1s 2ms/step - loss: 6.5297e-04
# Epoch 90/100
# 770/770 [==============================] - 1s 2ms/step - loss: 3.7008e-04
# Epoch 91/100
# 770/770 [==============================] - 1s 2ms/step - loss: 4.2016e-04
# Epoch 92/100
# 770/770 [==============================] - 1s 2ms/step - loss: 5.6653e-04
# Epoch 93/100
# 770/770 [==============================] - 2s 3ms/step - loss: 5.2376e-04
# Epoch 94/100
# 770/770 [==============================] - 2s 2ms/step - loss: 5.7029e-04
# Epoch 95/100
# 770/770 [==============================] - 1s 2ms/step - loss: 4.3139e-04
# Epoch 96/100
# 770/770 [==============================] - 1s 2ms/step - loss: 3.1112e-04
# Epoch 97/100
# 770/770 [==============================] - 1s 2ms/step - loss: 4.7368e-04
# Epoch 98/100
# 770/770 [==============================] - 1s 2ms/step - loss: 3.8689e-04
# Epoch 99/100
# 770/770 [==============================] - 1s 2ms/step - loss: 3.4639e-04
# Epoch 100/100
# 770/770 [==============================] - 1s 2ms/step - loss: 4.3326e-04
# 257/257 - 0s - loss: 0.0071 - 430ms/epoch - 2ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-a452fe5ba1fc> in <cell line: 4>()
#       2 nn.compile(loss="mse", optimizer="adam")
#       3 fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# ----> 4 model_loss, model_mse = nn.evaluate(X_test_scaled,y_test,verbose=2)
#       5
#       6
#
# TypeError: cannot unpack non-iterable float object
